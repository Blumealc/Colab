# %% [markdown]
# <a href="https://colab.research.google.com/github/Blumealc/Colab/blob/text_to_speech/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from gtts import gTTS

text_to_say = "è olio, infatti è olio l'ho detto io"
language = "it"

gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = True)

gtts_object.save("/content/gtts.wav")

# %%
from IPython.display import Audio

Audio("/content/gtts.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
